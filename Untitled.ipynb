# %%
# %pip install pytesseract
# Out:
# ...
#   Using cached pytesseract-0.3.10-py3-none-any.whl (14 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -illow (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ssffff\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\ssffff\anaconda3\lib\site-packages)
# ...

# %%
import numpy as np
import cv2
import base64
from PIL import Image
import matplotlib.pyplot as plt
import pytesseract
pytesseract.pytesseract.tesseract_cmd = (
    r"C:\\Users\\ssffff\\AppData\\Local\\Tesseract-OCR\\tesseract.exe"
)

# %%
def convert_b64_to_image(b64str):
    encoded_data = b64str.split(",")[1]
    nparr = np.frombuffer(base64.b64decode(encoded_data), np.uint8)
    img = cv2.imdecode(nparr, cv2.IMREAD_COLOR)
    return img

# %%
image = convert_b64_to_image("data:image/webp;base64,...")

actual_image = Image.fromarray(image, 'RGB')
actual_image
# Out:
# <PIL.Image.Image image mode=RGB size=1400x1533>

# %%
def extract_text_with_ocr(image):
    """
    returns the text extracted from an image. 
    """
    img = image
    # cv2.imshow('sample image', img)
    # cv2.waitKey(0)
    # cv2.destroyAllWindows()
    text = pytesseract.image_to_string(img)
    return (text.replace("\n", ' '))

# %%
print(image)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [253 255 253]
#   [253 255 253]
#   [253 255 253]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [253 255 253]
#   [253 255 253]
#   [253 255 253]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [253 255 253]
#   [253 255 253]
#   [253 255 253]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
img = cv2.imread(actual_image)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-376db1a39af2> in <module>
# ----> 1 img = cv2.imread(actual_image)
#
# TypeError: Can't convert object to 'str' for 'filename'

# %%
extract_text_with_ocr(image)
# Out:
# 'different.tilda.ws  VY  About Stenser Brothers  Stenser Brothers is a management consulting company that works with business innovators and help them get great achievements and bring those insights to life. For 10 years, we have been passionate about achieving better results that bring success and great fame for a brand. We proved ourselves like high professionals working with as small companies as with  honored brands. Every company has its conception and motto.  We work to develop unique products. Highly skilled professionals will help your business to grow on par with new technologies. We develop main conception of a company according to company target, develop strategies of competitive advantage. Staff selection is a very  important part of a management process.  We help to create a specialists portraits, develop ways of training of personnel. Developing of new products and business processes, timing developing, cost estimation, ways of  motivation, documentation and all life im
# ...
